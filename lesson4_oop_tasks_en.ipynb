# %% [markdown]
# # Lecture 4. OOP in Python
# ## Practice and homework
#
# **Topics:** classes, objects, `__init__`, `self`, methods, inheritance, `super()`.
#
# **How to solve:** replace `pass` with your code, press Shift+Enter.

# %% [markdown]
# ---
# # Part 1. In-class practice

# %% [markdown]
# ## Task 1. The `Rectangle` class
#
# Create a rectangle class:
# - attributes: `width`, `height`
# - method `area()`, returns the area
# - method `perimeter()`, returns the perimeter
# - method `is_square()`, returns `True` if the sides are equal
#
# ```python
# r = Rectangle(4, 6)
# print(r.area())         # 24
# print(r.perimeter())    # 20
# print(r.is_square())    # False
# ```

# %%
# Your code here
pass

# %% [markdown]
# ## Task 2. The `BankAccount` class
#
# Create a bank account class:
# - attributes: `owner`, `balance` (initially 0)
# - method `deposit(amount)`, top up the account
# - method `withdraw(amount)`, withdraw money (only if there are enough funds)
# - method `show_balance()`, print the current balance
#
# ```python
# acc = BankAccount("Ivan")
# acc.deposit(1000)
# acc.withdraw(300)
# acc.show_balance()      # Balance Ivan: 700
# ```

# %%
# Your code here
pass

# %% [markdown]
# ## Task 3. The `Counter` class
#
# Create a counter class:
# - attribute: `value` (initially 0)
# - method `increment()`, increase by 1
# - method `reset()`, reset to 0
# - method `get()`, return the current value
#
# ```python
# c = Counter()
# c.increment()
# c.increment()
# c.increment()
# print(c.get())   # 3
# c.reset()
# print(c.get())   # 0
# ```

# %%
# Your code here
pass

# %% [markdown]
# ## Task 4. The `Employee` and `Manager` hierarchy
#
# Create two classes.
#
# **`Employee`**:
# - attributes: `name`, `salary`
# - method `info()`, prints name and salary
#
# **`Manager(Employee)`** (subclass):
# - extra attribute: `team_size`
# - override `info()`, add information about the team size
# - method `bonus()`, returns 10% of the salary
#
# ```python
# emp = Employee("Ivan", 50000)
# emp.info()
# # Employee: Ivan, salary: 50000
#
# mgr = Manager("Anna", 80000, team_size=5)
# mgr.info()
# # Employee: Anna, salary: 80000, team: 5 people
#
# print(mgr.bonus())   # 8000
# ```

# %%
# Your code here
pass

# %% [markdown]
# ## Task 5. Shape hierarchy
#
# Create three classes.
#
# **`Shape`** (the base class):
# - attribute: `name`
# - method `area()`, returns 0 (will be overridden)
#
# **`Circle(Shape)`**:
# - extra attribute: `radius`
# - override `area()`, return π·r²
#
# **`Square(Shape)`**:
# - extra attribute: `side`
# - override `area()`, return side²
#
# Hint: `import math` for `math.pi`.

# %%
import math

# Your code here
pass

# %% [markdown]
# ---
# # Part 2. Homework

# %% [markdown]
# ## Homework 1. The `Book` class
#
# Implement a book class:
# - attributes: `title`, `author`, `pages`, `read_pages` (initially 0)
# - method `read(n)`, read `n` pages (with a check so that `read_pages` does not exceed `pages`)
# - method `progress()`, return the percent read
# - method `is_finished()`, return `True` if the book has been fully read
#
# ```python
# b = Book("1984", "Orwell", 320)
# b.read(80)
# print(b.progress())      # 25.0
# print(b.is_finished())   # False
# b.read(500)              # more than the remainder, we will read only up to the end
# print(b.is_finished())   # True
# ```

# %%
# Your code here
pass

# %% [markdown]
# ## Homework 2. Vehicle hierarchy
#
# Create three classes.
#
# **`Vehicle`**:
# - attributes: `brand`, `max_speed`
# - method `describe()`, prints the brand and the maximum speed
#
# **`Car(Vehicle)`**:
# - extra attribute: `fuel_type` (petrol / diesel / electric)
# - override `describe()`, add the fuel type
#
# **`ElectricCar(Car)`**:
# - extra attribute: `battery_capacity`
# - override `describe()`, add the battery capacity
# - `fuel_type` should default to `"electric"`
#
# ```python
# v = Vehicle("Honda", 220)
# v.describe()
#
# c = Car("Toyota", 180, "petrol")
# c.describe()
#
# e = ElectricCar("Tesla", 250, battery_capacity=85)
# e.describe()
# ```

# %%
# Your code here
pass

# %% [markdown]
# ## Homework 3 (bonus). The `SimpleStatistics` class
#
# Implement a simple statistics class:
# - takes a list of numbers in the constructor
# - method `mean()`, the mean
# - method `median()`, the median
# - method `mode()`, the mode (the most frequent value)
# - method `summary()`, prints all three values
#
# This is your first step toward understanding how the classes in `pandas` and `numpy` are built.
#
# ```python
# s = SimpleStatistics([1, 2, 2, 3, 4, 4, 4, 5])
# s.summary()
# # mean = 3.125
# # median = 3.5
# # mode = 4
# ```
#
# Hint: for the median, sort the list and take the middle element. For the mode, use a dictionary of frequencies or `collections.Counter`.

# %%
# Your code here
pass

# %% [markdown]
# ---
# ## What is next
#
# Once all the tasks are solved, the next lectures will cover:
# - magic methods (`__str__`, `__len__`, `__getitem__`)
# - decorators `@property`, `@classmethod`, `@staticmethod`
# - applying OOP in Data Science tasks
