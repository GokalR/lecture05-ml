# %% [markdown]
# # Лекция 4. ООП в Python
# ## Практика и домашнее задание
#
# **Темы:** классы, объекты, `__init__`, `self`, методы, наследование, `super()`.
#
# **Как решать:** замените `pass` на код, нажмите Shift+Enter.

# %% [markdown]
# ---
# # Часть 1. Практика на занятии

# %% [markdown]
# ## Задача 1. Класс `Rectangle`
#
# Создайте класс прямоугольника:
# - атрибуты: `width`, `height`
# - метод `area()`, возвращает площадь
# - метод `perimeter()`, возвращает периметр
# - метод `is_square()`, возвращает `True`, если стороны равны
#
# ```python
# r = Rectangle(4, 6)
# print(r.area())         # 24
# print(r.perimeter())    # 20
# print(r.is_square())    # False
# ```

# %%
# Ваш код здесь
pass

# %% [markdown]
# ## Задача 2. Класс `BankAccount`
#
# Создайте класс банковского счёта:
# - атрибуты: `owner` (владелец), `balance` (баланс, начально 0)
# - метод `deposit(amount)`, пополнить счёт
# - метод `withdraw(amount)`, снять деньги (только если хватает средств)
# - метод `show_balance()`, вывести текущий баланс
#
# ```python
# acc = BankAccount("Иван")
# acc.deposit(1000)
# acc.withdraw(300)
# acc.show_balance()      # Баланс Иван: 700
# ```

# %%
# Ваш код здесь
pass

# %% [markdown]
# ## Задача 3. Класс `Counter`
#
# Создайте класс-счётчик:
# - атрибут: `value` (изначально 0)
# - метод `increment()`, увеличить на 1
# - метод `reset()`, сбросить в 0
# - метод `get()`, вернуть текущее значение
#
# ```python
# c = Counter()
# c.increment()
# c.increment()
# c.increment()
# print(c.get())   # 3
# c.reset()
# print(c.get())   # 0
# ```

# %%
# Ваш код здесь
pass

# %% [markdown]
# ## Задача 4. Иерархия `Employee` и `Manager`
#
# Создайте два класса.
#
# **`Employee`** (сотрудник):
# - атрибуты: `name`, `salary`
# - метод `info()`, печатает имя и зарплату
#
# **`Manager(Employee)`** (менеджер, наследник):
# - дополнительный атрибут: `team_size`
# - переопределите `info()`, добавьте информацию о размере команды
# - метод `bonus()`, возвращает 10% от зарплаты
#
# ```python
# emp = Employee("Иван", 50000)
# emp.info()
# # Сотрудник: Иван, зарплата: 50000
#
# mgr = Manager("Анна", 80000, team_size=5)
# mgr.info()
# # Сотрудник: Анна, зарплата: 80000, команда: 5 человек
#
# print(mgr.bonus())   # 8000
# ```

# %%
# Ваш код здесь
pass

# %% [markdown]
# ## Задача 5. Иерархия фигур
#
# Создайте три класса.
#
# **`Shape`** (фигура), базовый класс:
# - атрибут: `name`
# - метод `area()`, возвращает 0 (будет переопределён)
#
# **`Circle(Shape)`** (круг):
# - дополнительный атрибут: `radius`
# - переопределите `area()`, вернуть π·r²
#
# **`Square(Shape)`** (квадрат):
# - дополнительный атрибут: `side`
# - переопределите `area()`, вернуть side²
#
# Подсказка: `import math` для `math.pi`.

# %%
import math

# Ваш код здесь
pass

# %% [markdown]
# ---
# # Часть 2. Домашнее задание

# %% [markdown]
# ## Домашка 1. Класс `Book`
#
# Реализуйте класс книги:
# - атрибуты: `title`, `author`, `pages`, `read_pages` (изначально 0)
# - метод `read(n)`, прочитать `n` страниц (с проверкой, чтобы `read_pages` не превышал `pages`)
# - метод `progress()`, вернуть процент прочитанного
# - метод `is_finished()`, вернуть `True`, если книга прочитана полностью
#
# ```python
# b = Book("1984", "Оруэлл", 320)
# b.read(80)
# print(b.progress())      # 25.0
# print(b.is_finished())   # False
# b.read(500)              # больше остатка, прочитаем только до конца
# print(b.is_finished())   # True
# ```

# %%
# Ваш код здесь
pass

# %% [markdown]
# ## Домашка 2. Иерархия транспортных средств
#
# Создайте три класса.
#
# **`Vehicle`**:
# - атрибуты: `brand`, `max_speed`
# - метод `describe()`, печатает марку и максимальную скорость
#
# **`Car(Vehicle)`**:
# - дополнительный атрибут: `fuel_type` (бензин / дизель / электро)
# - переопределите `describe()`, добавьте тип топлива
#
# **`ElectricCar(Car)`**:
# - дополнительный атрибут: `battery_capacity`
# - переопределите `describe()`, добавьте ёмкость батареи
# - `fuel_type` должен быть `"электро"` по умолчанию
#
# ```python
# v = Vehicle("Honda", 220)
# v.describe()
#
# c = Car("Toyota", 180, "бензин")
# c.describe()
#
# e = ElectricCar("Tesla", 250, battery_capacity=85)
# e.describe()
# ```

# %%
# Ваш код здесь
pass

# %% [markdown]
# ## Домашка 3 (со звёздочкой). Класс `SimpleStatistics`
#
# Реализуйте класс простой статистики:
# - принимает в конструкторе список чисел
# - метод `mean()`, среднее
# - метод `median()`, медиана
# - метод `mode()`, мода (самое частое значение)
# - метод `summary()`, печатает все три значения
#
# Это первый шаг к пониманию того, как устроены классы в `pandas` и `numpy`.
#
# ```python
# s = SimpleStatistics([1, 2, 2, 3, 4, 4, 4, 5])
# s.summary()
# # mean = 3.125
# # median = 3.5
# # mode = 4
# ```
#
# Подсказка: для медианы отсортируйте список и возьмите средний элемент. Для моды используйте словарь частот или `collections.Counter`.

# %%
# Ваш код здесь
pass

# %% [markdown]
# ---
# ## Что дальше
#
# Если все задания решены, в следующих лекциях разберём:
# - магические методы (`__str__`, `__len__`, `__getitem__`)
# - декораторы `@property`, `@classmethod`, `@staticmethod`
# - применение ООП в задачах Data Science
